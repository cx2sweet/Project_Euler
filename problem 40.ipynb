# %% [markdown]
# An irrational decimal fraction is created by concatenating the positive integers:
#
# 0.123456789101112131415161718192021...
#
# It can be seen that the 12th digit of the fractional part is 1.
#
# If dn represents the nth digit of the fractional part, find the value of the following expression.
#
# d1 × d10 × d100 × d1000 × d10000 × d100000 × d1000000

# %%
FLAG = True
count = 1
num = 1
prod = 1
while FLAG:
    digits = list(str(num))
    for i in digits:
        if count == 1: prod = prod*int(i)
        if count == 10: prod = prod*int(i)
        if count == 100: prod = prod*int(i)
        if count == 1000: prod = prod*int(i)
        if count == 10000: prod = prod*int(i)
        if count == 100000: prod = prod*int(i)
        if count == 1000000: prod = prod*int(i)
        count+=1
    num+=1
    if count>=1000000: FLAG = False

print(prod)
# Out:
# 210
